# %%
import pandas as pd

data_path = 'processed_data/training_data_lincs2020_chemfiltered_1201_l.pkl'

data = pd.read_pickle(data_path)

# %%
data.keys()
# Out:
# dict_keys(['X', 'y', 'folds', 'sample_meta', 'metadata', 'gene_names', 'compound_names', 'pert_to_idx'])

# %%
data['sample_meta']['cell_mfc_name'].value_counts()
# Out:
# cell_mfc_name
# MCF7              61483
# PC3               60601
# VCAP              49884
# A549              47318
# A375              44753
#                   ...
# MCF10A.WTLP.GM       54
# MCF10A.PTEN.M        54
# MCF10A.IDH1.HR       54
# MCF10A.EGFR.HD       53
# MCF10A.WTHP          52
# Name: count, Length: 86, dtype: int64

# %%
data['']
